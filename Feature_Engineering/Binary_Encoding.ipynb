# %%
import pandas as pd
from category_encoders import BinaryEncoder

df = pd.DataFrame({'Color': ['Red', 'Blue', 'Green', 'Yellow', 'Black']})

encoder = BinaryEncoder()
X_encoded = encoder.fit_transform(df)

print(X_encoded)
# Out:
#    Color_0  Color_1  Color_2
# 0        0        0        1
# 1        0        1        0
# 2        0        1        1
# 3        1        0        0
# 4        1        0        1
